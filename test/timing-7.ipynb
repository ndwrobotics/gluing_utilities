# %%
AttachSpec("~/CHIMP/CHIMP.spec");
Attach("../src/fast_gluing.m");
SetVerbose("Gluing", 1);

# %%
QQ := RationalsExtra(500);
R<x> := PolynomialRing(QQ);

Ys := [
HyperellipticCurve(R![2, 1, 3, 1, 1], R![0, 1, 1, 1]),
HyperellipticCurve(R![2, 1, 3, 1, 1], R![0, 1, 1, 1]),
HyperellipticCurve(R![2, 3, 4, 1, 1], R![1, 0, 0, 1]),
HyperellipticCurve(R![-1, 0, 0, 2, -3, 1], R![0, 1]),
HyperellipticCurve(R![-36, 6, 36, -17, -1, 1], R![1, 1])
];

Xs := [
EllipticCurve([0, 1, 1, -2376, -61851]),
EllipticCurve([0, 1, 1, -16, -31]),
EllipticCurve([0, 1, 1, -66, -349]),
EllipticCurve([0, 1, 1, 2540, -157433]),
EllipticCurve([0, 0, 1, 22857, 4273542])
];

# %%
time AllGeometricGluingsInvCCEfficient(Xs[1], Ys[1], QQ, 7);
# Out:
# Precision for finding H: 300
# ---------------------------
# H candidate number: 1 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 2 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 3 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 4 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 5 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 6 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 7 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 8 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 9 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 10 / 400
# ---------------------------
#
# ---------------------------
# ...

# %%
time AllGeometricGluingsInvCCEfficient(Xs[2], Ys[2], QQ, 7);
# Out:
# Precision for finding H: 300
# ---------------------------
# H candidate number: 1 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 2 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 3 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 4 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 5 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 6 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 7 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 8 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 9 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 10 / 400
# ---------------------------
#
# ---------------------------
# ...

# %%
time AllGeometricGluingsInvCCEfficient(Xs[3], Ys[3], QQ, 7);
# Out:
# Precision for finding H: 300
# ---------------------------
# H candidate number: 1 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 2 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 3 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 4 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 5 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 6 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 7 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 8 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 9 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 10 / 400
# ---------------------------
#
# ---------------------------
# ...

# %%
time AllGeometricGluingsInvCCEfficient(Xs[4], Ys[4], QQ, 7);
# Out:
# Precision for finding H: 300
# ---------------------------
# H candidate number: 1 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 2 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 3 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 4 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 5 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 6 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 7 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 8 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 9 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 10 / 400
# ---------------------------
#
# ---------------------------
# ...

# %%
time AllGeometricGluingsInvCCEfficient(Xs[5], Ys[5], QQ, 7);
# Out:
# Precision for finding H: 300
# ---------------------------
# H candidate number: 1 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 2 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 3 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 4 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 5 / 400
# Found candidate H
# ---------------------------
#
# ---------------------------
# H candidate number: 6 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 7 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 8 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 9 / 400
# ---------------------------
#
# ---------------------------
# H candidate number: 10 / 400
# ---------------------------
#
# ...

# %%
time AllGeometricGluingsInvCC(Xs[1], Ys[1], QQ, 7);
# Out:
# -----------------------
# Subgroup number: 1
# -----------------------
# -----------------------
# Subgroup number: 2
# -----------------------
# -----------------------
# Subgroup number: 3
# -----------------------
# -----------------------
# Subgroup number: 4
# -----------------------
# -----------------------
# Subgroup number: 5
# -----------------------
# -----------------------
# Subgroup number: 6
# -----------------------
# -----------------------
# Subgroup number: 7
# -----------------------
# -----------------------
# Subgroup number: 8
# -----------------------
# -----------------------
# Subgroup number: 9
# -----------------------
# -----------------------
# Subgroup number: 10
# -----------------------
# -----------------------
# Subgroup number: 11
# -----------------------
# -----------------------
# Subgroup number: 12
# -----------------------
# -----------------------
# Subgroup number: 13
# -----------------------
# -----------------------
# ...

# %%
time AllGeometricGluingsInvCC(Xs[2], Ys[2], QQ, 7);

# %%
time AllGeometricGluingsInvCC(Xs[3], Ys[3], QQ, 7);

# %%
time AllGeometricGluingsInvCC(Xs[4], Ys[4], QQ, 7);

# %%
time AllGeometricGluingsInvCC(Xs[5], Ys[5], QQ, 7);
